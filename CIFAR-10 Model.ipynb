# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import cifar10

import matplotlib.pyplot as plt
import numpy as np

# %%
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()

train_images, test_images = train_images / 255.0, test_images / 255.0
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 2s 0us/step

# %%
input = layers.Input(shape=(32, 32, 3))

x = layers.Conv2D(32, (3, 3), activation='relu')(input)
x = layers.MaxPooling2D((2, 2))(input)
x = layers.Conv2D(64, (3, 3), activation='relu')(x)
x = layers.MaxPooling2D((2, 2))(x)
x = layers.Conv2D(128, (3, 3), activation='relu')(x)
x = layers.Dropout(0.4)(x)
x = layers.Flatten()(x)

output = layers.Dense(10, activation='softmax')(x)

model = models.Model(inputs=input, outputs=output)

# %%
model.compile(optimizer='adam',
              loss="sparse_categorical_crossentropy",
              metrics=['accuracy'])

# %%
history = model.fit(train_images, train_labels, epochs=40,
                    validation_data=(test_images, test_labels))
# Out:
# Epoch 1/40
# 1563/1563 [==============================] - 12s 7ms/step - loss: 1.5986 - accuracy: 0.4206 - val_loss: 1.4001 - val_accuracy: 0.5041
# Epoch 2/40
# 1563/1563 [==============================] - 11s 7ms/step - loss: 1.3257 - accuracy: 0.5277 - val_loss: 1.2450 - val_accuracy: 0.5586
# Epoch 3/40
# 1563/1563 [==============================] - 11s 7ms/step - loss: 1.2167 - accuracy: 0.5706 - val_loss: 1.1213 - val_accuracy: 0.6044
# Epoch 4/40
# 1563/1563 [==============================] - 11s 7ms/step - loss: 1.1423 - accuracy: 0.5996 - val_loss: 1.0783 - val_accuracy: 0.6184
# Epoch 5/40
# 1563/1563 [==============================] - 11s 7ms/step - loss: 1.0923 - accuracy: 0.6155 - val_loss: 1.0319 - val_accuracy: 0.6370
# Epoch 6/40
# 1563/1563 [==============================] - 10s 7ms/step - loss: 1.0542 - accuracy: 0.6284 - val_loss: 1.0170 - val_accuracy: 0.6398
# Epoch 7/40
# 1563/1563 [==============================] - 11s 7ms/step - loss: 1.0223 - accuracy: 0.6429 - val_loss: 1.0511 - val_accuracy: 0.6313
# Epoch 8/40
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.9916 - accuracy: 0.6532 - val_loss: 0.9773 - val_accuracy: 0.6629
# Epoch 9/40
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.9682 - accuracy: 0.6605 - val_loss: 0.9765 - val_accuracy: 0.6599
# Epoch 10/40
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.9563 - accuracy: 0.6628 - val_loss: 0.9618 - val_accuracy: 0.6661
# Epoch 11/40
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.9339 - accuracy: 0.6723 - val_loss: 0.9744 - val_accuracy: 0.6605
# Epoch 12/40
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.9137 - accuracy: 0.6788 - val_loss: 0.9633 - val_accuracy: 0.6599
# Epoch 13/40
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.9025 - accuracy: 0.6845 - val_loss: 0.9382 - val_accuracy: 0.6751
# Epoch 14/40
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.8848 - accuracy: 0.6876 - val_loss: 0.9840 - val_accuracy: 0.6621
# Epoch 15/40
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.8712 - accuracy: 0.6956 - val_loss: 0.9493 - val_accuracy: 0.6724
# Epoch 16/40
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.8546 - accuracy: 0.6995 - val_loss: 0.9531 - val_accuracy: 0.6721
# Epoch 17/40
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.8411 - accuracy: 0.7047 - val_loss: 0.9536 - val_accuracy: 0.6712
# Epoch 18/40
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.8379 - accuracy: 0.7046 - val_loss: 0.9235 - val_accuracy: 0.6789
# Epoch 19/40
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.8160 - accuracy: 0.7113 - val_loss: 0.9565 - val_accuracy: 0.6740
# Epoch 20/40
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.8109 - accuracy: 0.7141 - val_loss: 0.9247 - val_accuracy: 0.6807
# Epoch 21/40
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.7953 - accuracy: 0.7201 - val_loss: 0.9460 - val_accuracy: 0.6781
# Epoch 22/40
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.7877 - accuracy: 0.7239 - val_loss: 0.9771 - val_accuracy: 0.6734
# Epoch 23/40
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.7811 - accuracy: 0.7272 - val_loss: 0.9270 - val_accuracy: 0.6831
# Epoch 24/40
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.7645 - accuracy: 0.7313 - val_loss: 0.9280 - val_accuracy: 0.6804
# Epoch 25/40
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.7577 - accuracy: 0.7327 - val_loss: 0.9919 - val_accuracy: 0.6672
# Epoch 26/40
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.7517 - accuracy: 0.7354 - val_loss: 0.9444 - val_accuracy: 0.6725
# Epoch 27/40
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.7461 - accuracy: 0.7369 - val_loss: 0.9245 - val_accuracy: 0.6856
# Epoch 28/40
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.7371 - accuracy: 0.7387 - val_loss: 0.9387 - val_accuracy: 0.6809
# Epoch 29/40
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.7216 - accuracy: 0.7452 - val_loss: 0.9266 - val_accuracy: 0.6878
# Epoch 30/40
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.7233 - accuracy: 0.7441 - val_loss: 0.9458 - val_accuracy: 0.6847
# Epoch 31/40
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.7135 - accuracy: 0.7468 - val_loss: 0.9452 - val_accuracy: 0.6842
# Epoch 32/40
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.7069 - accuracy: 0.7500 - val_loss: 0.9364 - val_accuracy: 0.6828
# Epoch 33/40
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6958 - accuracy: 0.7554 - val_loss: 0.9270 - val_accuracy: 0.6866
# Epoch 34/40
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6920 - accuracy: 0.7531 - val_loss: 0.9524 - val_accuracy: 0.6861
# Epoch 35/40
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6825 - accuracy: 0.7590 - val_loss: 0.9272 - val_accuracy: 0.6886
# Epoch 36/40
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6780 - accuracy: 0.7599 - val_loss: 0.9434 - val_accuracy: 0.6903
# Epoch 37/40
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.6686 - accuracy: 0.7618 - val_loss: 0.9506 - val_accuracy: 0.6855
# Epoch 38/40
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6645 - accuracy: 0.7620 - val_loss: 0.9533 - val_accuracy: 0.6930
# Epoch 39/40
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6613 - accuracy: 0.7657 - val_loss: 0.9605 - val_accuracy: 0.6817
# Epoch 40/40
# 1563/1563 [==============================] - 11s 7ms/step - loss: 0.6583 - accuracy: 0.7647 - val_loss: 0.9392 - val_accuracy: 0.6872

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels, verbose=2)
print(f'\nTest accuracy: {test_acc}')
# Out:
# 313/313 - 1s - loss: 0.9392 - accuracy: 0.6872 - 991ms/epoch - 3ms/step
#
# Test accuracy: 0.6872000098228455

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_images(images, labels, predictions):
    plt.figure(figsize=(10, 10))
    for i in range(len(images)):
        plt.subplot(5, 5, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(images[i], cmap=plt.cm.binary)
        predicted_label = np.argmax(predictions[i])
        true_label = int(labels[i])
        if predicted_label == true_label:
            color = 'green'
        else:
            color = 'red'
        plt.xlabel(f'{class_names[predicted_label]}', color=color)
    plt.show()

class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

num_images = 25
test_images_subset = test_images[:num_images]
true_labels_subset = test_labels[:num_images]

predictions = model.predict(test_images_subset)
plot_images(test_images_subset, true_labels_subset, predictions)
# Out:
# 1/1 [==============================] - 0s 87ms/step
# <ipython-input-20-9e424383b264>:13: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   true_label = int(labels[i])
